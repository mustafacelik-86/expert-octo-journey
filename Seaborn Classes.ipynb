# %%
# !pip install matplotlib

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt # matplotlib içerisindeki pyplot modülünü plt olarak import etmek için kullanırız.
import matplotlib as mpl # sadece tekil olarak matplotlib'i import etmek için kullanırız.

import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
print(mpl.__version__)
# Out:
# 3.9.2

# %%
print(sns.__version__)
# Out:
# 0.13.2

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
taxis = sns.load_dataset("taxis")

# %%
taxis.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
taxis.shape
# Out:
# (6433, 14)

# %%
taxis.sample(10)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 1801 2019-03-22 11:15:41 2019-03-22 11:30:10           1      1.80  10.5
# 2703 2019-03-09 01:20:58 2019-03-09 01:38:34           1      6.36  20.0
# 4052 2019-03-06 20:27:40 2019-03-06 20:39:22           1      1.35   9.0
# 1992 2019-03-02 23:25:29 2019-03-02 23:48:59           2     10.97  32.0
# 3244 2019-03-14 20:33:38 2019-03-14 20:53:01           0      2.50  13.5
# 5782 2019-03-30 10:51:51 2019-03-30 11:06:56           1      8.28  23.5
# 685  2019-03-06 23:07:04 2019-03-06 23:24:10           1      6.40  19.5
# 6392 2019-03-30 09:36:30 2019-03-30 09:57:49           1      4.36  15.0
# 4540 2019-03-14 09:48:30 2019-03-14 09:57:43           5      1.22   7.5
# 227  2019-03-14 14:28:42 2019-03-14 14:56:54           1      3.79  19.5
#
#        tip  tolls  total   color      payment              pickup_zone  \
# 1801  2.76   0.00  16.56  yellow  credit card           Midtown Center
# ...

# %%
taxis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(data = taxis, x = "fare", y = "tip")
plt.show()

# %% [markdown]
# ## regression plot

# %%
sns.regplot(data = taxis, x = "fare", y = "tip")
plt.show()

# %%
# iki değişkenin arasındaki inceliyoruz.
# scatter'lara uygun olacak şekilde bir trend çizgisi oluşturuyor.
# regresyon: bağımsız değişken ve bağımlı değişken arasındaki ilişkiyi matematiksel olarak açıklama işlemi.
# daha önce aldığı verileri işleyerek, bütün datayı temsil edebilecek bir patern kuruyor. 
# gölgeler hata payını temsil eder. (ci = confident interval) default= %95

# %%
plt.figure(figsize =(10,5))

sns.scatterplot(x = taxis["fare"], y = taxis["tip"])
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x = taxis["fare"], y = taxis["tip"], hue = taxis["payment"])
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x = taxis["fare"], y = taxis["tip"], hue = taxis["color"])
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x = taxis["fare"], y = taxis["tip"], hue = taxis["passengers"])
plt.legend(loc = "lower right")
plt.show()

# %%
# style, hue ile aynı işi yapar ama renklerle değil de şekillerle anlatır

plt.figure(figsize = (10,5))
sns.scatterplot(x = taxis["fare"], y = taxis["tip"], style = taxis["passengers"])
plt.legend(loc = "lower right")
plt.show()

# %%
# hem style, hem hue

plt.figure(figsize = (10,5))
sns.scatterplot(x = taxis["fare"], y = taxis["tip"], style = taxis["passengers"], hue = taxis["color"])
plt.legend(loc = "lower right")
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize = (10,5))

sns.scatterplot(data = taxis, x ="fare", y = "tip", style = "color", ax = ax[0]) #birinci grafik olsun demek istedik
sns.scatterplot(data = taxis, x ="fare", y = "tip", hue = "passengers", ax = ax[1]) #ikinci grafik
plt.show()

# %%
#renk paleti

plt.figure(figsize = (10,5))
sns.scatterplot(taxis, x = "fare", y = "tip", style = "passengers", hue = "color", palette = "viridis")
plt.legend(loc = "lower right")
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(taxis, x = "fare", y = "tip", style = "passengers", hue = "color", palette = "plasma")
plt.legend(loc = "lower right")
plt.show()

# %%
#şeffafllık ayarı

plt.figure(figsize = (10,5))
sns.scatterplot(taxis, x = "fare", y = "tip", alpha = 0.5)
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(taxis, x = "fare", y = "tip", style = "color", hue = "passengers", palette = "tab10", alpha = 0.5, s = 100) #s = size
plt.show()

# %% [markdown]
# ## Distplot (Distribution Plot)

# %%
sns.displot(data = taxis, x = "fare")
plt.show()

# %%
#kde plot, dağılımı daha yumuşak bir gösterimle bize verir
# kde = kernel density estimation

sns.displot(data = taxis, x = "fare", kde = True)
plt.show()

# %%
#sütun sayısını azalttık, o yüzden y eksenindeki değerler arttı

sns.displot(data = taxis, x = "fare", kde = True, bins = 30)
plt.show()

# %%
# dist, hist'ten türediği için tip olarak onu da içermiş

sns.displot(data = taxis, x = "fare", kind = "hist")
plt.show()

# %%
# normalize ederek verdi

sns.displot(data = taxis, x = "fare", kind = "kde")
plt.show()

# %%
# aspect parametresi ile x eksenini genişlettik. Böylece grafik rahat rahat sığdı

sns.displot(data = taxis, x = "fare", bins = 300, kde = True, aspect = 5)
plt.show()

# %%
#şimdi de x ve y eksenindeki rakalamları değiştirelim.

sns.displot(data = taxis, x = "fare", bins = 300, kde = True, aspect = 5)

plt.xticks(range(0,150,10))
plt.yticks(range(0,350,25))

plt.show()

# %% [markdown]
# ## Hist Plot

# %%
plt.figure(figsize = (10,8))
sns.histplot(data = taxis, x = "fare", bins = 50, kde = True)
plt.show()

# %%
# iki farklı grafiği OOM ile, yan yana çizdirdik

fig, ax = plt.subplots(1,2, figsize = (8,6))

sns.scatterplot(data = taxis, x = "fare", y = "tip", s = 20, hue = "color", ax = ax[0])
sns.histplot(data = taxis, x = "fare", bins = 50, kde = True, ax = ax[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Rug Plot

# %%
fig, ax = plt.subplots(figsize = (5,5))

sns.rugplot(taxis, x = "tip", height = 0.2)
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize = (8,6))

sns.rugplot(data = taxis, x = "tip", hue = "color", height = 0.3, ax = ax[0])
sns.histplot(data = taxis, x = "tip", bins = 50, kde = True, ax = ax[1])

plt.tight_layout()
plt.show()

# %%
#displot'un içine rug plot da yazılabilir.

sns.displot(data = taxis, x = "fare", kde = True, rug =True)
plt.show()

# %%
#displot'un içine yazılan rug, ayrı bir değişkene atanıp düzenlenebilir.

rug_kws = {"linewidth" : 2, "alpha" : 0.5, "height" : 0.1}

sns.displot(taxis, x = "tip", kde = True, rug = True, rug_kws=rug_kws)
plt.show()

# %% [markdown]
# # Style

# %%
sns.set(style = "dark")
sns.histplot(taxis, x = "tip", kde = True)

plt.show()

# %%
sns.set(style = "whitegrid")
sns.histplot(taxis, x = "tip", kde = True);

# %%
sns.set(style = "darkgrid")
sns.histplot(taxis, x = "tip", kde = True);

# %%
sns.set(style = "white")
sns.histplot(taxis, x = "tip", kde = True);

# %% [markdown]
# # KDE Plot

# %% [markdown]
# ## Penguins Dataset
#
# Antarktika'daki üç farklı penguen türüne (Adelie, Chinstrap ve Gentoo) ait özellikler içerir. Genellikle veri görselleştirme, istatistiksel analiz ve makine öğrenimi uygulamalarında kullanılır. Clasification tahmini yapacak algoritmada kullanacağız
# Veri seti değişkenleri:
#
# **species**: Penguen türü (Adelie, Chinstrap, Gentoo).
#
# **island**: Penguenlerin gözlemlendiği ada (örneğin Biscoe, Dream, Torgersen).
#
# **bill_length_mm**: Penguenlerin gagalarının uzunluğu milimetre cinsinden.
#
# **bill_depth_mm**: Penguenlerin gagalarının derinliği milimetre cinsinden.
#
# **flipper_length_mm**: Penguenlerin yüzgeç uzunlukları milimetre cinsinden.
#
# **body_mass_g**: Penguenlerin vücut ağırlıkları gram cinsinden.
#
# **sex**: Penguenin cinsiyeti (erkek veya dişi).
#
# Bu veri seti, penguenlerin morfolojik ölçümlerini ve türlerini içerir ve bu özellikler arasındaki ilişkileri keşfetmek için kullanılabilir. Örneğin, farklı penguen türlerinin boyutları ve vücut ağırlıkları arasındaki farklar gibi konular bu veri seti ile analiz edilebilir.

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.sample(5)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 282     Gentoo     Biscoe            45.7           13.9              214.0
# 164  Chinstrap      Dream            47.0           17.3              185.0
# 128     Adelie  Torgersen            39.0           17.1              191.0
# 343     Gentoo     Biscoe            49.9           16.1              213.0
# 223     Gentoo     Biscoe            50.0           15.2              218.0
#
#      body_mass_g     sex
# 282       4400.0  Female
# 164       3700.0  Female
# 128       3050.0  Female
# 343       5400.0    Male
# 223       5700.0    Male

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
sns.set(style = "dark")
sns.kdeplot(data = penguins, x = "body_mass_g")

plt.show()

# %%
sns.kdeplot(data = penguins, x = "body_mass_g", hue = "sex")
plt.show()

# %%
# gölge ekledik

sns.kdeplot(data = penguins, x = "body_mass_g", hue = "sex", shade = True)
plt.show()

# %%
# cinslere göre hue yapalım

sns.kdeplot(data = penguins, x = "body_mass_g", hue = "species", shade = True)
plt.show()

# %%
# bu sefer de gaga uzunluğuna bakalım

sns.kdeplot(data = penguins, x = "bill_length_mm", hue = "sex", shade = True)
plt.show()

# %% [markdown]
# ## KDE İzohips Benzeri Eğri Grafiği (Contour Dist Plot)

# %%
# datayı tanımak amacıyla, makine öğrenmesinde kullanılır
# yoğunluk noktalarını verir
# KDE'den farkı, iki değişken üzerinden yoğunluk görebilmemizdir.

# %%
tips = sns.load_dataset("tips")
sns.kdeplot(data = tips, x = "total_bill", y = "tip")
plt.show()

# %%
sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "red")
plt.show()

# %%
sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "red", shade = True)
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize = (10,5))

sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "red", shade = True, ax = ax[0])
sns.scatterplot(data = tips, x = "total_bill", y = "tip", color = "green", ax = ax[1])

plt.show()

# %%
fig, ax = plt.subplots(2,2, figsize = (10,5))

sns.kdeplot(data = tips, x = "total_bill", y = "tip", color = "green", shade = True, ax = ax[0][0])
sns.scatterplot(data = tips, x = "total_bill", y = "tip", color = "green", ax = ax[0][1])
sns.histplot(data = tips, x = "total_bill", color = "green", ax = ax[1][0])
sns.rugplot(data = tips, x = "total_bill", color = "green", height = 0.3 , ax = ax[1][1])

plt.tight_layout()
plt.show()

# %% [markdown]
# # MPG Veri Seti
#
# Genellikle "miles per gallon" yani galon başına mil olarak ifade edilen yakıt tüketim verimliliği üzerine çeşitli analizler yapmak için kullanılır. Veri seti, 1980'lerin sonlarına kadar Amerika Birleşik Devletleri'nde üretilen çeşitli otomobillerin özelliklerini içerir.
#
# mpg veri seti:
#
# mpg: Araçların galon başına kat edebildiği mil (yakıt verimliliği) olarak ölçülür.
#
# cylinders: Motorun silindir sayısı.
#
# displacement: Motor hacmi, genellikle inç küp (ci) veya santimetre küp (cc) olarak ifade edilir.
#
# horsepower: Motor gücü, beygir gücü (hp) cinsinden.
#
# weight: Araç ağırlığı, pound veya kilogram cinsinden.
#
# acceleration: 0'dan 60 mil/saat hıza çıkış süresi, saniye cinsinden.
#
# model_year: Araç model yılı.
#
# origin: Araç üretim ülkesi.
#
# name: Araç model adı.
#
# Bu veri seti, otomobillerin yakıt verimliliği ile bu özellikler arasındaki ilişkileri analiz etmek için kullanılır. Örneğin, araştırmacılar motor hacmi, ağırlık ve silindir sayısı gibi faktörlerin mpg üzerindeki etkisini inceleyebilirler.

# %%
cars = sns.load_dataset("mpg")

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.displot(x = "weight", data = cars)
plt.show()

# %%
sns.displot(x = "weight", data = cars, hue = "origin")
plt.show()

# %%
sns.displot(x = "weight", data = cars, hue = "origin", kde = True)
plt.show()

# %%
# şimdi cars datasetini biraz daraltacağız

cars.cylinders.unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
sns.displot(data = cars[cars.cylinders.isin([4,6,8])], 
            x = "weight",
            col = "origin",
            row = "cylinders",
            hue = "cylinders",
            palette = "plasma")
plt.show()

# %% [markdown]
# ## Countplot

# %%
# Kategorik değerler kullanılır

# %%
sns.countplot(data = tips, x = "day")
plt.show()

# %%
# bu plot tipinde hue verince farklı barlar çıkar.

fig, ax = plt.subplots(figsize = (10, 5))
ax_tip = sns.countplot(data = tips, x = "day", hue = "sex")

#bu kısım da barların üzerine tam rakamları yazdırmaya yarar
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.15, p.get_height()+1))

# %%
sns.countplot(x = "cylinders", data = cars)
plt.show()

# %%
sns.countplot(x = "model_year", data = cars)
plt.show()

# %%
sns.countplot(x = "model_year", data = cars, hue = "origin")
plt.show()

# %% [markdown]
# # barplot

# %%
#bar grafiğin default hesaplaması mean'dir.

sns.barplot(x = "sex", y = "tip", data = tips, palette = "Set2")
plt.show()

# %%
# bu sefer de toplam

sns.barplot(x = "sex", y = "tip", data = tips, palette = "Set2", estimator = np.sum)
plt.show()

# %%
# çubuğu ortadan kaldıralım

sns.barplot(x = "sex", y = "tip", data = tips, palette = "Set2", estimator = np.sum, ci = None)
plt.show()

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(x = "day", y = "tip", data = tips)
plt.show()

# %%
#yukarıdaki görselde Thursday sağdan çarpık, friday ise soldan çarpık

# %%
sns.boxplot(x = "day", y = "tip", data = tips, hue = "sex")
plt.show()

# %%
# kategorik değer olan day'i y'ye verince grafik yan yattı

sns.boxplot(x = "tip", y = "day", data = tips, hue = "sex");
