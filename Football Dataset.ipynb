# %%
# (Gerekirse) kurulum
# !pip install -q --upgrade kagglehub

import kagglehub
path = kagglehub.dataset_download("saurabhshahane/statsbomb-football-data")
print("Dataset root:", path)
# Out:
# Dataset root: C:\Users\stmus\.cache\kagglehub\datasets\saurabhshahane\statsbomb-football-data\versions\1181

# %%
import pandas as pd, json
from pandas import json_normalize
from pathlib import Path

# --- 0) KaggleHub'ın verdiği kök yolu kullan ---
DATA_DIR = Path(r"C:\Users\stmus\.cache\kagglehub\datasets\saurabhshahane\statsbomb-football-data\versions\1181") / "data"
print("DATA_DIR:", DATA_DIR)

# --- 1) competitions ---
comps = pd.read_json(DATA_DIR / "competitions.json")
print("competitions:", comps.shape)

# --- 2) matches dosyaları ve mevcut events dosyaları ---
match_files = sorted((DATA_DIR / "matches").rglob("*.json"))
events_dir = DATA_DIR / "events"
event_ids = {int(p.stem) for p in events_dir.glob("*.json")}
print("Bulunan match dosyası sayısı:", len(match_files), "| Bulunan events dosyası sayısı:", len(event_ids))

# Herhangi bir matches dosyasından, events'i gerçekten olan ilk match_id'yi seç
match_id = None
chosen_matches_file = None
for mf in match_files:
    m = pd.read_json(mf)
    ids = m["match_id"].astype(int)
    ok = [i for i in ids if i in event_ids]
    if ok:
        match_id = int(ok[0])
        chosen_matches_file = mf
        matches = m  # ilk bulunanı tut
        break

if match_id is None:
    raise FileNotFoundError("Hiçbir matches dosyasındaki match_id için events/*.json bulunamadı.")

print("Seçilen matches dosyası:", chosen_matches_file.name, "| Seçilen match_id:", match_id)

# --- 3) events'i ROBUST şekilde oku ---
events_path = events_dir / f"{match_id}.json"
print("events_path:", events_path)

def read_events_any(path: Path) -> pd.DataFrame:
    # önce NDJSON dene
    try:
        return pd.read_json(path, lines=True)
    except ValueError:
        # JSON dizi (list) formatına düş
        with open(path, "r", encoding="utf-8") as f:
            data = json.load(f)  # list[dict]
        return pd.json_normalize(data)

events = read_events_any(events_path)
print("events satır:", len(events))

# --- 4) düzleştir (gerekirse) ---
# read_events_any zaten DataFrame döndürüyor; nested alanları normalize edelim
ev = json_normalize(events.to_dict(orient="records"))

# --- 5) işe yarar sütunlar ---
cols = [
    "id","index","period","timestamp","minute","second",
    "type.name","team.name","possession_team.name","player.name",
    "location","pass.end_location","pass.height.name","pass.outcome.name",
    "shot.outcome.name","shot.statsbomb_xg","shot.body_part.name","shot.technique.name"
]
ev = ev[[c for c in cols if c in ev.columns]].copy()

# --- 6) koordinatları ayır ---
for col in ["location", "pass.end_location"]:
    if col in ev.columns:
        xy = ev[col].apply(pd.Series)
        xy.columns = [f"{col}_x", f"{col}_y"]
        ev = pd.concat([ev, xy], axis=1)

# --- 7) hızlı alt tablolar ---
shots  = ev[ev.get("type.name").eq("Shot")] if "type.name" in ev.columns else pd.DataFrame()
passes = ev[ev.get("type.name").eq("Pass")] if "type.name" in ev.columns else pd.DataFrame()

print("events:", ev.shape, "| shots:", shots.shape, "| passes:", passes.shape)
ev.head(3)
# Out:
# DATA_DIR: C:\Users\stmus\.cache\kagglehub\datasets\saurabhshahane\statsbomb-football-data\versions\1181\data
# competitions: (75, 12)
# Bulunan match dosyası sayısı: 75 | Bulunan events dosyası sayısı: 3464
# Seçilen matches dosyası: 1.json | Seçilen match_id: 9880
# events_path: C:\Users\stmus\.cache\kagglehub\datasets\saurabhshahane\statsbomb-football-data\versions\1181\data\events\9880.json
# events satır: 3947
# events: (3947, 22) | shots: (29, 22) | passes: (1162, 22)
#                                      id  index  period     timestamp  minute  \
# 0  2f8319f2-f34c-47fd-977b-332324d7d86c      1       1  00:00:00.000       0
# 1  43fae5ba-b810-4f74-a16d-cd176c51664f      2       1  00:00:00.000       0
# 2  67ef9f5e-fa09-47a3-ba34-9db104d76596      3       1  00:00:00.000       0
#
#    second    type.name  team.name possession_team.name player.name  ...  \
# 0       0  Starting XI  Barcelona            Barcelona         NaN  ...
# 1       0  Starting XI   Valencia            Barcelona         NaN  ...
# 2       0   Half Start  Barcelona            Barcelona         NaN  ...
#
#   pass.height.name pass.outcome.name shot.outcome.name shot.statsbomb_xg  \
# 0              NaN               NaN               NaN               NaN
# 1              NaN               NaN               NaN               NaN
# 2              NaN               NaN               NaN               NaN
#
#   shot.body_part.name  shot.technique.name location_x location_y  \
# 0                 NaN                  NaN        NaN        NaN
# 1                 NaN                  NaN        NaN        NaN
# 2                 NaN                  NaN        NaN        NaN
#
#    pass.end_location_x  pass.end_location_y
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
#
# [3 rows x 22 columns]

# %%
from pandas import json_normalize

# matches tablosunu düzleştir (takım adları kolay ulaşılır olsun)
mnorm = json_normalize(matches.to_dict(orient="records"))

cols = ["match_id",
        "home_team.home_team_name",
        "away_team.away_team_name",
        "match_date"]
print(mnorm[cols].head(10))

# Örn: Barcelona içeren maçları listele
m_barca = mnorm[mnorm["home_team.home_team_name"].str.contains("Barcelona", na=False) |
                mnorm["away_team.away_team_name"].str.contains("Barcelona", na=False)]
m_barca[cols].head(10)
# Out:
#    match_id home_team.home_team_name away_team.away_team_name  match_date
# 0      9880                Barcelona                 Valencia  2018-04-14
# 1      9912   RC Deportivo La Coruña                Barcelona  2018-04-29
# 2      9924                Barcelona              Real Madrid  2018-05-06
# 3      9855                Barcelona            Athletic Club  2018-03-18
# 4      9827               Las Palmas                Barcelona  2018-03-01
# 5      9799                    Eibar                Barcelona  2018-02-17
# 6      9636                Barcelona               Las Palmas  2017-10-01
# 7      9609                Barcelona                    Eibar  2017-09-19
# 8      9575                Barcelona               Real Betis  2017-08-20
# 9      9928                Barcelona               Villarreal  2018-05-09
#    match_id home_team.home_team_name away_team.away_team_name  match_date
# 0      9880                Barcelona                 Valencia  2018-04-14
# 1      9912   RC Deportivo La Coruña                Barcelona  2018-04-29
# 2      9924                Barcelona              Real Madrid  2018-05-06
# 3      9855                Barcelona            Athletic Club  2018-03-18
# 4      9827               Las Palmas                Barcelona  2018-03-01
# 5      9799                    Eibar                Barcelona  2018-02-17
# 6      9636                Barcelona               Las Palmas  2017-10-01
# 7      9609                Barcelona                    Eibar  2017-09-19
# 8      9575                Barcelona               Real Betis  2017-08-20
# 9      9928                Barcelona               Villarreal  2018-05-09

# %%
# Seçtiğin maçı yükle
MATCH_ID = 9924 # buraya istediğin id'yi yaz
events = read_events_any((DATA_DIR / "events" / f"{MATCH_ID}.json"))
ev = json_normalize(events.to_dict(orient="records"))

# alt tablolar
shots  = ev[ev.get("type.name").eq("Shot")].copy()
passes = ev[ev.get("type.name").eq("Pass")].copy()

# %%
shots.head()
# Out:
#                                        id  index  period     timestamp  \
# 184  b89e1c69-a2f3-4ba4-bb18-17ede738ce9d    185       1  00:03:03.474
# 354  5acf5296-cca3-40a5-84d1-90ae01e6f558    355       1  00:06:58.473
# 471  f38c74de-91ba-44b1-b95b-fc7e421536ea    472       1  00:09:22.688
# 660  c1f8c418-e744-4dc8-8297-5b48c95c2c01    661       1  00:14:00.470
# 823  f402b24b-32b1-488e-a14f-de82862adf59    824       1  00:18:46.543
#
#      minute  second  possession  duration  type.id type.name  ...  \
# 184       3       3           6  0.056362       16      Shot  ...
# 354       6      58          15  0.791119       16      Shot  ...
# 471       9      22          25  0.451381       16      Shot  ...
# 660      14       0          32  0.474980       16      Shot  ...
# 823      18      46          41  0.872694       16      Shot  ...
#
#      bad_behaviour.card.name substitution.outcome.id  \
# 184                      NaN                     NaN
# 354                      NaN                     NaN
# 471                      NaN                     NaN
# 660                      NaN                     NaN
# 823                      NaN                     NaN
#
#      substitution.outcome.name substitution.replacement.id  \
# 184                        NaN                         NaN
# 354                        NaN                         NaN
# 471                        NaN                         NaN
# 660                        NaN                         NaN
# 823                        NaN                         NaN
#
#      substitution.replacement.name ball_recovery.offensive  pass.cut_back  \
# 184                            NaN                     NaN            NaN
# 354                            NaN                     NaN            NaN
# 471                            NaN                     NaN            NaN
# 660                            NaN                     NaN            NaN
# 823                            NaN                     NaN            NaN
#
#     dribble.nutmeg block.offensive pass.inswinging
# 184            NaN             NaN             NaN
# 354            NaN             NaN             NaN
# 471            NaN             NaN             NaN
# 660            NaN             NaN             NaN
# 823            NaN             NaN             NaN
#
# [5 rows x 118 columns]

# %%
passes.head()
# Out:
#                                       id  index  period     timestamp  minute  \
# 4   d40fa88a-4084-4a97-968d-9c02540537f5      5       1  00:00:00.867       0
# 7   d8608e08-b199-4dbf-b09d-e880b501b4dd      8       1  00:00:03.113       0
# 10  0a579b70-76ca-450a-a705-bd45dc2a45c4     11       1  00:00:06.092       0
# 13  9e00d2f8-28af-4fa9-b0a8-939628855ff4     14       1  00:00:07.742       0
# 16  7ba572f6-415a-4bab-af5c-f857df6ae7e7     17       1  00:00:09.863       0
#
#     second  possession  duration  type.id type.name  ...  \
# 4        0           2  0.922238       30      Pass  ...
# 7        3           2  1.200000       30      Pass  ...
# 10       6           2  1.203526       30      Pass  ...
# 13       7           2  1.859370       30      Pass  ...
# 16       9           2  1.403779       30      Pass  ...
#
#     bad_behaviour.card.name substitution.outcome.id  \
# 4                       NaN                     NaN
# 7                       NaN                     NaN
# 10                      NaN                     NaN
# 13                      NaN                     NaN
# 16                      NaN                     NaN
#
#     substitution.outcome.name substitution.replacement.id  \
# 4                         NaN                         NaN
# 7                         NaN                         NaN
# 10                        NaN                         NaN
# 13                        NaN                         NaN
# 16                        NaN                         NaN
#
#     substitution.replacement.name ball_recovery.offensive  pass.cut_back  \
# 4                             NaN                     NaN            NaN
# 7                             NaN                     NaN            NaN
# 10                            NaN                     NaN            NaN
# 13                            NaN                     NaN            NaN
# 16                            NaN                     NaN            NaN
#
#    dribble.nutmeg block.offensive pass.inswinging
# 4             NaN             NaN             NaN
# 7             NaN             NaN             NaN
# 10            NaN             NaN             NaN
# 13            NaN             NaN             NaN
# 16            NaN             NaN             NaN
#
# [5 rows x 118 columns]

# %%
passes.shape
# Out:
# (1161, 118)

# %%
shots.shape
# Out:
# (28, 118)

# %%
passes.info
# Out:
# <bound method DataFrame.info of                                         id  index  period     timestamp  \
# 4     d40fa88a-4084-4a97-968d-9c02540537f5      5       1  00:00:00.867
# 7     d8608e08-b199-4dbf-b09d-e880b501b4dd      8       1  00:00:03.113
# 10    0a579b70-76ca-450a-a705-bd45dc2a45c4     11       1  00:00:06.092
# 13    9e00d2f8-28af-4fa9-b0a8-939628855ff4     14       1  00:00:07.742
# 16    7ba572f6-415a-4bab-af5c-f857df6ae7e7     17       1  00:00:09.863
# ...                                    ...    ...     ...           ...
# 3813  69152c21-36fc-4465-a69e-ae3ba0cbdde6   3814       2  00:48:55.011
# 3816  ade7c562-2e56-4a98-88bf-eb8706310d04   3817       2  00:48:58.363
# 3822  76e1239c-e93c-4525-a610-5403f26a6bb7   3823       2  00:49:22.862
# 3824  a7e10ee1-7425-47e7-8c0d-f818b32b2021   3825       2  00:49:26.134
# 3826  ec3c1c6d-3242-477a-bb1b-c52e0b5c3ceb   3827       2  00:49:41.468
#
#       minute  second  possession  duration  type.id type.name  ...  \
# 4          0       0           2  0.922238       30      Pass  ...
# 7          0       3           2  1.200000       30      Pass  ...
# 10         0       6           2  1.203526       30      Pass  ...
# 13         0       7           2  1.859370       30      Pass  ...
# 16         0       9           2  1.403779       30      Pass  ...
# ...      ...     ...         ...       ...      ...       ...  ...
# 3813      93      55         169  2.128628       30      Pass  ...
# 3816      93      58         169  1.464532       30      Pass  ...
# 3822      94      22         170  2.326303       30      Pass  ...
# 3824      94      26         170  1.311139       30      Pass  ...
# 3826      94      41         171  1.227390       30      Pass  ...
#
#       bad_behaviour.card.name substitution.outcome.id  \
# 4                         NaN                     NaN
# 7                         NaN                     NaN
# 10                        NaN                     NaN
# 13                        NaN                     NaN
# 16                        NaN                     NaN
# ...                       ...                     ...
# 3813                      NaN                     NaN
# 3816                      NaN                     NaN
# 3822                      NaN                     NaN
# 3824                      NaN                     NaN
# 3826                      NaN                     NaN
#
#       substitution.outcome.name substitution.replacement.id  \
# 4                           NaN                         NaN
# 7                           NaN                         NaN
# 10                          NaN                         NaN
# 13                          NaN                         NaN
# 16                          NaN                         NaN
# ...                         ...                         ...
# 3813                        NaN                         NaN
# 3816                        NaN                         NaN
# 3822                        NaN                         NaN
# 3824                        NaN                         NaN
# 3826                        NaN                         NaN
#
#       substitution.replacement.name ball_recovery.offensive  pass.cut_back  \
# 4                               NaN                     NaN            NaN
# 7                               NaN                     NaN            NaN
# 10                              NaN                     NaN            NaN
# 13                              NaN                     NaN            NaN
# 16                              NaN                     NaN            NaN
# ...                             ...                     ...            ...
# 3813                            NaN                     NaN            NaN
# 3816                            NaN                     NaN            NaN
# 3822                            NaN                     NaN            NaN
# 3824                            NaN                     NaN            NaN
# 3826                            NaN                     NaN            NaN
#
#      dribble.nutmeg block.offensive pass.inswinging
# 4               NaN             NaN             NaN
# 7               NaN             NaN             NaN
# 10              NaN             NaN             NaN
# 13              NaN             NaN             NaN
# 16              NaN             NaN             NaN
# ...             ...             ...             ...
# 3813            NaN             NaN             NaN
# 3816            NaN             NaN             NaN
# 3822            NaN             NaN             NaN
# 3824            NaN             NaN             NaN
# 3826            NaN             NaN             NaN
#
# [1161 rows x 118 columns]>

# %%
passes.describe
# Out:
# <bound method NDFrame.describe of                                         id  index  period     timestamp  \
# 4     d40fa88a-4084-4a97-968d-9c02540537f5      5       1  00:00:00.867
# 7     d8608e08-b199-4dbf-b09d-e880b501b4dd      8       1  00:00:03.113
# 10    0a579b70-76ca-450a-a705-bd45dc2a45c4     11       1  00:00:06.092
# 13    9e00d2f8-28af-4fa9-b0a8-939628855ff4     14       1  00:00:07.742
# 16    7ba572f6-415a-4bab-af5c-f857df6ae7e7     17       1  00:00:09.863
# ...                                    ...    ...     ...           ...
# 3813  69152c21-36fc-4465-a69e-ae3ba0cbdde6   3814       2  00:48:55.011
# 3816  ade7c562-2e56-4a98-88bf-eb8706310d04   3817       2  00:48:58.363
# 3822  76e1239c-e93c-4525-a610-5403f26a6bb7   3823       2  00:49:22.862
# 3824  a7e10ee1-7425-47e7-8c0d-f818b32b2021   3825       2  00:49:26.134
# 3826  ec3c1c6d-3242-477a-bb1b-c52e0b5c3ceb   3827       2  00:49:41.468
#
#       minute  second  possession  duration  type.id type.name  ...  \
# 4          0       0           2  0.922238       30      Pass  ...
# 7          0       3           2  1.200000       30      Pass  ...
# 10         0       6           2  1.203526       30      Pass  ...
# 13         0       7           2  1.859370       30      Pass  ...
# 16         0       9           2  1.403779       30      Pass  ...
# ...      ...     ...         ...       ...      ...       ...  ...
# 3813      93      55         169  2.128628       30      Pass  ...
# 3816      93      58         169  1.464532       30      Pass  ...
# 3822      94      22         170  2.326303       30      Pass  ...
# 3824      94      26         170  1.311139       30      Pass  ...
# 3826      94      41         171  1.227390       30      Pass  ...
#
#       bad_behaviour.card.name substitution.outcome.id  \
# 4                         NaN                     NaN
# 7                         NaN                     NaN
# 10                        NaN                     NaN
# 13                        NaN                     NaN
# 16                        NaN                     NaN
# ...                       ...                     ...
# 3813                      NaN                     NaN
# 3816                      NaN                     NaN
# 3822                      NaN                     NaN
# 3824                      NaN                     NaN
# 3826                      NaN                     NaN
#
#       substitution.outcome.name substitution.replacement.id  \
# 4                           NaN                         NaN
# 7                           NaN                         NaN
# 10                          NaN                         NaN
# 13                          NaN                         NaN
# 16                          NaN                         NaN
# ...                         ...                         ...
# 3813                        NaN                         NaN
# 3816                        NaN                         NaN
# 3822                        NaN                         NaN
# 3824                        NaN                         NaN
# 3826                        NaN                         NaN
#
#       substitution.replacement.name ball_recovery.offensive  pass.cut_back  \
# 4                               NaN                     NaN            NaN
# 7                               NaN                     NaN            NaN
# 10                              NaN                     NaN            NaN
# 13                              NaN                     NaN            NaN
# 16                              NaN                     NaN            NaN
# ...                             ...                     ...            ...
# 3813                            NaN                     NaN            NaN
# 3816                            NaN                     NaN            NaN
# 3822                            NaN                     NaN            NaN
# 3824                            NaN                     NaN            NaN
# 3826                            NaN                     NaN            NaN
#
#      dribble.nutmeg block.offensive pass.inswinging
# 4               NaN             NaN             NaN
# 7               NaN             NaN             NaN
# 10              NaN             NaN             NaN
# 13              NaN             NaN             NaN
# 16              NaN             NaN             NaN
# ...             ...             ...             ...
# 3813            NaN             NaN             NaN
# 3816            NaN             NaN             NaN
# 3822            NaN             NaN             NaN
# 3824            NaN             NaN             NaN
# 3826            NaN             NaN             NaN
#
# [1161 rows x 118 columns]>

# %%
shots.columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'type.id', 'type.name',
#        ...
#        'bad_behaviour.card.name', 'substitution.outcome.id',
#        'substitution.outcome.name', 'substitution.replacement.id',
#        'substitution.replacement.name', 'ball_recovery.offensive',
#        'pass.cut_back', 'dribble.nutmeg', 'block.offensive',
#        'pass.inswinging'],
#       dtype='object', length=118)

# %%
shots.describe
# Out:
# <bound method NDFrame.describe of                                         id  index  period     timestamp  \
# 184   b89e1c69-a2f3-4ba4-bb18-17ede738ce9d    185       1  00:03:03.474
# 354   5acf5296-cca3-40a5-84d1-90ae01e6f558    355       1  00:06:58.473
# 471   f38c74de-91ba-44b1-b95b-fc7e421536ea    472       1  00:09:22.688
# 660   c1f8c418-e744-4dc8-8297-5b48c95c2c01    661       1  00:14:00.470
# 823   f402b24b-32b1-488e-a14f-de82862adf59    824       1  00:18:46.543
# 1065  df052d1d-6b66-42c7-a380-f76a0dc10c8e   1066       1  00:23:56.034
# 1159  272f61f9-8802-496a-8f89-d91bdd648f53   1160       1  00:25:31.635
# 1173  e31e92e2-4905-4ddc-b975-ae7e264b1bfc   1174       1  00:26:06.778
# 1237  bc7fa36b-507c-4e91-a9b9-964b692068d8   1238       1  00:27:11.266
# 1640  028ec253-7f76-4cec-87ec-ec30383f9766   1641       1  00:37:45.355
# 1746  9d1fa265-8332-4dd4-b602-d2a37141bf35   1747       1  00:39:52.331
# 1815  89d2458d-6668-4b4a-9c09-54459488c8cf   1816       1  00:41:31.490
# 1959  f45dfddf-6b5c-423a-9666-f557e240b1f5   1960       1  00:48:22.314
# 2084  3555ce99-3030-405f-813e-212a67c096f4   2085       2  00:01:43.483
# 2349  e15da2de-7404-43b8-a223-55a6497d7be3   2350       2  00:06:31.923
# 2369  0ca38903-2d66-4306-80db-ce106bc445b7   2370       2  00:06:50.314
# 2711  b1c7886d-d062-4333-b7ec-eca6bfcb5822   2712       2  00:17:36.766
# 2802  fa7a4dd1-ca13-4f47-9f23-c251a14e362f   2803       2  00:19:25.049
# 2946  876aee8d-f2ed-4abe-8a7f-23e42815befe   2947       2  00:21:40.762
# 3035  5aa93bcf-1bbb-41e5-925b-34ba6d72d069   3036       2  00:24:12.296
# 3094  012bd39c-29ae-42b7-b603-688dbd50e579   3095       2  00:26:52.591
# 3411  9dcf8bf4-2946-4e43-80e2-ab4a50ffaa49   3412       2  00:34:43.139
# 3431  eba1204b-f642-490f-850d-d4bfc69d797f   3432       2  00:35:14.331
# 3459  44c04d3a-4e24-46d5-ab6e-b8bd40301475   3460       2  00:36:08.320
# 3480  2bab6165-cb0e-4b0e-aa37-56f9abc4c7f3   3481       2  00:36:38.242
# 3484  6cb3824d-aa2a-4d7a-96af-a8a26336a64a   3485       2  00:37:25.542
# 3764  44aa6b44-7449-483d-91bd-2d5643d5c7d8   3765       2  00:47:58.928
# 3819  3fe08fc9-3dcd-450b-867b-90a8caa90145   3820       2  00:49:02.600
#
#       minute  second  possession  duration  type.id type.name  ...  \
# 184        3       3           6  0.056362       16      Shot  ...
# 354        6      58          15  0.791119       16      Shot  ...
# 471        9      22          25  0.451381       16      Shot  ...
# 660       14       0          32  0.474980       16      Shot  ...
# 823       18      46          41  0.872694       16      Shot  ...
# 1065      23      56          53  0.581820       16      Shot  ...
# 1159      25      31          57  0.933832       16      Shot  ...
# 1173      26       6          59  0.099851       16      Shot  ...
# 1237      27      11          59  0.675082       16      Shot  ...
# 1640      37      45          73  1.099002       16      Shot  ...
# 1746      39      52          75  0.852573       16      Shot  ...
# 1815      41      31          79  1.484520       16      Shot  ...
# 1959      48      22          88  0.302678       16      Shot  ...
# 2084      46      43          91  1.056845       16      Shot  ...
# 2349      51      31          99  0.439481       16      Shot  ...
# 2369      51      50         102  0.893583       16      Shot  ...
# 2711      62      36         121  0.416602       16      Shot  ...
# 2802      64      25         122  0.272659       16      Shot  ...
# 2946      66      40         124  0.437875       16      Shot  ...
# 3035      69      12         129  0.318033       16      Shot  ...
# 3094      71      52         132  0.708056       16      Shot  ...
# 3411      79      43         145  0.625729       16      Shot  ...
# 3431      80      14         146  0.833762       16      Shot  ...
# 3459      81       8         149  1.187642       16      Shot  ...
# 3480      81      38         151  0.439621       16      Shot  ...
# 3484      82      25         152  1.310075       16      Shot  ...
# 3764      92      58         166  0.217740       16      Shot  ...
# 3819      94       2         169  0.272837       16      Shot  ...
#
#       bad_behaviour.card.name substitution.outcome.id  \
# 184                       NaN                     NaN
# 354                       NaN                     NaN
# 471                       NaN                     NaN
# 660                       NaN                     NaN
# 823                       NaN                     NaN
# 1065                      NaN                     NaN
# 1159                      NaN                     NaN
# 1173                      NaN                     NaN
# 1237                      NaN                     NaN
# 1640                      NaN                     NaN
# 1746                      NaN                     NaN
# 1815                      NaN                     NaN
# 1959                      NaN                     NaN
# 2084                      NaN                     NaN
# 2349                      NaN                     NaN
# 2369                      NaN                     NaN
# 2711                      NaN                     NaN
# 2802                      NaN                     NaN
# 2946                      NaN                     NaN
# 3035                      NaN                     NaN
# 3094                      NaN                     NaN
# 3411                      NaN                     NaN
# 3431                      NaN                     NaN
# 3459                      NaN                     NaN
# 3480                      NaN                     NaN
# 3484                      NaN                     NaN
# 3764                      NaN                     NaN
# 3819                      NaN                     NaN
#
#       substitution.outcome.name substitution.replacement.id  \
# 184                         NaN                         NaN
# 354                         NaN                         NaN
# 471                         NaN                         NaN
# 660                         NaN                         NaN
# 823                         NaN                         NaN
# 1065                        NaN                         NaN
# 1159                        NaN                         NaN
# 1173                        NaN                         NaN
# 1237                        NaN                         NaN
# 1640                        NaN                         NaN
# 1746                        NaN                         NaN
# 1815                        NaN                         NaN
# 1959                        NaN                         NaN
# 2084                        NaN                         NaN
# 2349                        NaN                         NaN
# 2369                        NaN                         NaN
# 2711                        NaN                         NaN
# 2802                        NaN                         NaN
# 2946                        NaN                         NaN
# 3035                        NaN                         NaN
# 3094                        NaN                         NaN
# 3411                        NaN                         NaN
# 3431                        NaN                         NaN
# 3459                        NaN                         NaN
# 3480                        NaN                         NaN
# 3484                        NaN                         NaN
# 3764                        NaN                         NaN
# 3819                        NaN                         NaN
#
#       substitution.replacement.name ball_recovery.offensive  pass.cut_back  \
# 184                             NaN                     NaN            NaN
# 354                             NaN                     NaN            NaN
# 471                             NaN                     NaN            NaN
# 660                             NaN                     NaN            NaN
# 823                             NaN                     NaN            NaN
# 1065                            NaN                     NaN            NaN
# 1159                            NaN                     NaN            NaN
# 1173                            NaN                     NaN            NaN
# 1237                            NaN                     NaN            NaN
# 1640                            NaN                     NaN            NaN
# 1746                            NaN                     NaN            NaN
# 1815                            NaN                     NaN            NaN
# 1959                            NaN                     NaN            NaN
# 2084                            NaN                     NaN            NaN
# 2349                            NaN                     NaN            NaN
# 2369                            NaN                     NaN            NaN
# 2711                            NaN                     NaN            NaN
# 2802                            NaN                     NaN            NaN
# 2946                            NaN                     NaN            NaN
# 3035                            NaN                     NaN            NaN
# 3094                            NaN                     NaN            NaN
# 3411                            NaN                     NaN            NaN
# 3431                            NaN                     NaN            NaN
# 3459                            NaN                     NaN            NaN
# 3480                            NaN                     NaN            NaN
# 3484                            NaN                     NaN            NaN
# 3764                            NaN                     NaN            NaN
# 3819                            NaN                     NaN            NaN
#
#      dribble.nutmeg block.offensive pass.inswinging
# 184             NaN             NaN             NaN
# 354             NaN             NaN             NaN
# 471             NaN             NaN             NaN
# 660             NaN             NaN             NaN
# 823             NaN             NaN             NaN
# 1065            NaN             NaN             NaN
# 1159            NaN             NaN             NaN
# 1173            NaN             NaN             NaN
# 1237            NaN             NaN             NaN
# 1640            NaN             NaN             NaN
# 1746            NaN             NaN             NaN
# 1815            NaN             NaN             NaN
# 1959            NaN             NaN             NaN
# 2084            NaN             NaN             NaN
# 2349            NaN             NaN             NaN
# 2369            NaN             NaN             NaN
# 2711            NaN             NaN             NaN
# 2802            NaN             NaN             NaN
# 2946            NaN             NaN             NaN
# 3035            NaN             NaN             NaN
# 3094            NaN             NaN             NaN
# 3411            NaN             NaN             NaN
# 3431            NaN             NaN             NaN
# 3459            NaN             NaN             NaN
# 3480            NaN             NaN             NaN
# 3484            NaN             NaN             NaN
# 3764            NaN             NaN             NaN
# 3819            NaN             NaN             NaN
#
# [28 rows x 118 columns]>

# %%
shots.info
# Out:
# <bound method DataFrame.info of                                         id  index  period     timestamp  \
# 184   b89e1c69-a2f3-4ba4-bb18-17ede738ce9d    185       1  00:03:03.474
# 354   5acf5296-cca3-40a5-84d1-90ae01e6f558    355       1  00:06:58.473
# 471   f38c74de-91ba-44b1-b95b-fc7e421536ea    472       1  00:09:22.688
# 660   c1f8c418-e744-4dc8-8297-5b48c95c2c01    661       1  00:14:00.470
# 823   f402b24b-32b1-488e-a14f-de82862adf59    824       1  00:18:46.543
# 1065  df052d1d-6b66-42c7-a380-f76a0dc10c8e   1066       1  00:23:56.034
# 1159  272f61f9-8802-496a-8f89-d91bdd648f53   1160       1  00:25:31.635
# 1173  e31e92e2-4905-4ddc-b975-ae7e264b1bfc   1174       1  00:26:06.778
# 1237  bc7fa36b-507c-4e91-a9b9-964b692068d8   1238       1  00:27:11.266
# 1640  028ec253-7f76-4cec-87ec-ec30383f9766   1641       1  00:37:45.355
# 1746  9d1fa265-8332-4dd4-b602-d2a37141bf35   1747       1  00:39:52.331
# 1815  89d2458d-6668-4b4a-9c09-54459488c8cf   1816       1  00:41:31.490
# 1959  f45dfddf-6b5c-423a-9666-f557e240b1f5   1960       1  00:48:22.314
# 2084  3555ce99-3030-405f-813e-212a67c096f4   2085       2  00:01:43.483
# 2349  e15da2de-7404-43b8-a223-55a6497d7be3   2350       2  00:06:31.923
# 2369  0ca38903-2d66-4306-80db-ce106bc445b7   2370       2  00:06:50.314
# 2711  b1c7886d-d062-4333-b7ec-eca6bfcb5822   2712       2  00:17:36.766
# 2802  fa7a4dd1-ca13-4f47-9f23-c251a14e362f   2803       2  00:19:25.049
# 2946  876aee8d-f2ed-4abe-8a7f-23e42815befe   2947       2  00:21:40.762
# 3035  5aa93bcf-1bbb-41e5-925b-34ba6d72d069   3036       2  00:24:12.296
# 3094  012bd39c-29ae-42b7-b603-688dbd50e579   3095       2  00:26:52.591
# 3411  9dcf8bf4-2946-4e43-80e2-ab4a50ffaa49   3412       2  00:34:43.139
# 3431  eba1204b-f642-490f-850d-d4bfc69d797f   3432       2  00:35:14.331
# 3459  44c04d3a-4e24-46d5-ab6e-b8bd40301475   3460       2  00:36:08.320
# 3480  2bab6165-cb0e-4b0e-aa37-56f9abc4c7f3   3481       2  00:36:38.242
# 3484  6cb3824d-aa2a-4d7a-96af-a8a26336a64a   3485       2  00:37:25.542
# 3764  44aa6b44-7449-483d-91bd-2d5643d5c7d8   3765       2  00:47:58.928
# 3819  3fe08fc9-3dcd-450b-867b-90a8caa90145   3820       2  00:49:02.600
#
#       minute  second  possession  duration  type.id type.name  ...  \
# 184        3       3           6  0.056362       16      Shot  ...
# 354        6      58          15  0.791119       16      Shot  ...
# 471        9      22          25  0.451381       16      Shot  ...
# 660       14       0          32  0.474980       16      Shot  ...
# 823       18      46          41  0.872694       16      Shot  ...
# 1065      23      56          53  0.581820       16      Shot  ...
# 1159      25      31          57  0.933832       16      Shot  ...
# 1173      26       6          59  0.099851       16      Shot  ...
# 1237      27      11          59  0.675082       16      Shot  ...
# 1640      37      45          73  1.099002       16      Shot  ...
# 1746      39      52          75  0.852573       16      Shot  ...
# 1815      41      31          79  1.484520       16      Shot  ...
# 1959      48      22          88  0.302678       16      Shot  ...
# 2084      46      43          91  1.056845       16      Shot  ...
# 2349      51      31          99  0.439481       16      Shot  ...
# 2369      51      50         102  0.893583       16      Shot  ...
# 2711      62      36         121  0.416602       16      Shot  ...
# 2802      64      25         122  0.272659       16      Shot  ...
# 2946      66      40         124  0.437875       16      Shot  ...
# 3035      69      12         129  0.318033       16      Shot  ...
# 3094      71      52         132  0.708056       16      Shot  ...
# 3411      79      43         145  0.625729       16      Shot  ...
# 3431      80      14         146  0.833762       16      Shot  ...
# 3459      81       8         149  1.187642       16      Shot  ...
# 3480      81      38         151  0.439621       16      Shot  ...
# 3484      82      25         152  1.310075       16      Shot  ...
# 3764      92      58         166  0.217740       16      Shot  ...
# 3819      94       2         169  0.272837       16      Shot  ...
#
#       bad_behaviour.card.name substitution.outcome.id  \
# 184                       NaN                     NaN
# 354                       NaN                     NaN
# 471                       NaN                     NaN
# 660                       NaN                     NaN
# 823                       NaN                     NaN
# 1065                      NaN                     NaN
# 1159                      NaN                     NaN
# 1173                      NaN                     NaN
# 1237                      NaN                     NaN
# 1640                      NaN                     NaN
# 1746                      NaN                     NaN
# 1815                      NaN                     NaN
# 1959                      NaN                     NaN
# 2084                      NaN                     NaN
# 2349                      NaN                     NaN
# 2369                      NaN                     NaN
# 2711                      NaN                     NaN
# 2802                      NaN                     NaN
# 2946                      NaN                     NaN
# 3035                      NaN                     NaN
# 3094                      NaN                     NaN
# 3411                      NaN                     NaN
# 3431                      NaN                     NaN
# 3459                      NaN                     NaN
# 3480                      NaN                     NaN
# 3484                      NaN                     NaN
# 3764                      NaN                     NaN
# 3819                      NaN                     NaN
#
#       substitution.outcome.name substitution.replacement.id  \
# 184                         NaN                         NaN
# 354                         NaN                         NaN
# 471                         NaN                         NaN
# 660                         NaN                         NaN
# 823                         NaN                         NaN
# 1065                        NaN                         NaN
# 1159                        NaN                         NaN
# 1173                        NaN                         NaN
# 1237                        NaN                         NaN
# 1640                        NaN                         NaN
# 1746                        NaN                         NaN
# 1815                        NaN                         NaN
# 1959                        NaN                         NaN
# 2084                        NaN                         NaN
# 2349                        NaN                         NaN
# 2369                        NaN                         NaN
# 2711                        NaN                         NaN
# 2802                        NaN                         NaN
# 2946                        NaN                         NaN
# 3035                        NaN                         NaN
# 3094                        NaN                         NaN
# 3411                        NaN                         NaN
# 3431                        NaN                         NaN
# 3459                        NaN                         NaN
# 3480                        NaN                         NaN
# 3484                        NaN                         NaN
# 3764                        NaN                         NaN
# 3819                        NaN                         NaN
#
#       substitution.replacement.name ball_recovery.offensive  pass.cut_back  \
# 184                             NaN                     NaN            NaN
# 354                             NaN                     NaN            NaN
# 471                             NaN                     NaN            NaN
# 660                             NaN                     NaN            NaN
# 823                             NaN                     NaN            NaN
# 1065                            NaN                     NaN            NaN
# 1159                            NaN                     NaN            NaN
# 1173                            NaN                     NaN            NaN
# 1237                            NaN                     NaN            NaN
# 1640                            NaN                     NaN            NaN
# 1746                            NaN                     NaN            NaN
# 1815                            NaN                     NaN            NaN
# 1959                            NaN                     NaN            NaN
# 2084                            NaN                     NaN            NaN
# 2349                            NaN                     NaN            NaN
# 2369                            NaN                     NaN            NaN
# 2711                            NaN                     NaN            NaN
# 2802                            NaN                     NaN            NaN
# 2946                            NaN                     NaN            NaN
# 3035                            NaN                     NaN            NaN
# 3094                            NaN                     NaN            NaN
# 3411                            NaN                     NaN            NaN
# 3431                            NaN                     NaN            NaN
# 3459                            NaN                     NaN            NaN
# 3480                            NaN                     NaN            NaN
# 3484                            NaN                     NaN            NaN
# 3764                            NaN                     NaN            NaN
# 3819                            NaN                     NaN            NaN
#
#      dribble.nutmeg block.offensive pass.inswinging
# 184             NaN             NaN             NaN
# 354             NaN             NaN             NaN
# 471             NaN             NaN             NaN
# 660             NaN             NaN             NaN
# 823             NaN             NaN             NaN
# 1065            NaN             NaN             NaN
# 1159            NaN             NaN             NaN
# 1173            NaN             NaN             NaN
# 1237            NaN             NaN             NaN
# 1640            NaN             NaN             NaN
# 1746            NaN             NaN             NaN
# 1815            NaN             NaN             NaN
# 1959            NaN             NaN             NaN
# 2084            NaN             NaN             NaN
# 2349            NaN             NaN             NaN
# 2369            NaN             NaN             NaN
# 2711            NaN             NaN             NaN
# 2802            NaN             NaN             NaN
# 2946            NaN             NaN             NaN
# 3035            NaN             NaN             NaN
# 3094            NaN             NaN             NaN
# 3411            NaN             NaN             NaN
# 3431            NaN             NaN             NaN
# 3459            NaN             NaN             NaN
# 3480            NaN             NaN             NaN
# 3484            NaN             NaN             NaN
# 3764            NaN             NaN             NaN
# 3819            NaN             NaN             NaN
#
# [28 rows x 118 columns]>

# %%
#Tüm sütunları genişçe görebilmek için

with pd.option_context("display.max_columns", None, "display.width", None, "display.max_colwidth", None):
    display(passes.head(3))
# Out:
#                                       id  index  period     timestamp  minute  \
# 4   d40fa88a-4084-4a97-968d-9c02540537f5      5       1  00:00:00.867       0
# 7   d8608e08-b199-4dbf-b09d-e880b501b4dd      8       1  00:00:03.113       0
# 10  0a579b70-76ca-450a-a705-bd45dc2a45c4     11       1  00:00:06.092       0
#
#     second  possession  duration  type.id type.name  possession_team.id  \
# 4        0           2  0.922238       30      Pass                 220
# 7        3           2  1.200000       30      Pass                 220
# 10       6           2  1.203526       30      Pass                 220
#
#    possession_team.name  play_pattern.id play_pattern.name  team.id  \
# 4           Real Madrid                9     From Kick Off      220
# 7           Real Madrid                9     From Kick Off      220
# 10          Real Madrid                9     From Kick Off      220
#
#       team.name  tactics.formation tactics.lineup  \
# 4   Real Madrid                NaN            NaN
# 7   Real Madrid                NaN            NaN
# 10  Real Madrid                NaN            NaN
#
#                             related_events      location  player.id  \
# 4   [6287d4b1-b61d-46ea-b1a0-3dad62c953cc]  [61.0, 40.1]    19677.0
# 7   [1dc284ed-a045-4bde-97f2-a3361ce19945]  [48.7, 33.0]     5574.0
# 10  [8b448299-6910-4147-86c8-0a9b35c605c5]  [33.3, 15.0]     5201.0
#
#             player.name  position.id         position.name  pass.recipient.id  \
# 4         Karim Benzema         23.0        Center Forward             5574.0
# 7            Toni Kroos         15.0  Left Center Midfield             5201.0
# 10  Sergio Ramos García          5.0      Left Center Back             5485.0
#
#     pass.recipient.name  pass.length  pass.angle  pass.height.id  \
# 4            Toni Kroos    12.873616   -2.841952             1.0
# 7   Sergio Ramos García    22.196396   -2.131306             1.0
# 10       Raphaël Varane    43.141857    1.614851             1.0
#
#    pass.height.name pass.end_location  pass.body_part.id pass.body_part.name  \
# 4       Ground Pass      [48.7, 36.3]               40.0          Right Foot
# 7       Ground Pass      [36.9, 14.2]               40.0          Right Foot
# 10      Ground Pass      [31.4, 58.1]               40.0          Right Foot
#
#     pass.type.id pass.type.name carry.end_location pass.switch under_pressure  \
# 4           65.0       Kick Off                NaN         NaN            NaN
# 7            NaN            NaN                NaN         NaN            NaN
# 10           NaN            NaN                NaN        True            NaN
#
#     pass.outcome.id pass.outcome.name  ball_receipt.outcome.id  \
# 4               NaN               NaN                      NaN
# 7               NaN               NaN                      NaN
# 10              NaN               NaN                      NaN
#
#    ball_receipt.outcome.name pass.aerial_won  duel.type.id duel.type.name  \
# 4                        NaN             NaN           NaN            NaN
# 7                        NaN             NaN           NaN            NaN
# 10                       NaN             NaN           NaN            NaN
#
#     duel.outcome.id duel.outcome.name ball_recovery.recovery_failure  \
# 4               NaN               NaN                            NaN
# 7               NaN               NaN                            NaN
# 10              NaN               NaN                            NaN
#
#    pass.assisted_shot_id pass.shot_assist  shot.statsbomb_xg  \
# 4                    NaN              NaN                NaN
# 7                    NaN              NaN                NaN
# 10                   NaN              NaN                NaN
#
#    shot.end_location shot.key_pass_id shot.first_time  shot.technique.id  \
# 4                NaN              NaN             NaN                NaN
# 7                NaN              NaN             NaN                NaN
# 10               NaN              NaN             NaN                NaN
#
#    shot.technique.name  shot.body_part.id shot.body_part.name  shot.type.id  \
# 4                  NaN                NaN                 NaN           NaN
# 7                  NaN                NaN                 NaN           NaN
# 10                 NaN                NaN                 NaN           NaN
#
#    shot.type.name  shot.outcome.id shot.outcome.name shot.freeze_frame  out  \
# 4             NaN              NaN               NaN               NaN  NaN
# 7             NaN              NaN               NaN               NaN  NaN
# 10            NaN              NaN               NaN               NaN  NaN
#
#    goalkeeper.end_location  goalkeeper.type.id goalkeeper.type.name  \
# 4                      NaN                 NaN                  NaN
# 7                      NaN                 NaN                  NaN
# 10                     NaN                 NaN                  NaN
#
#     goalkeeper.position.id goalkeeper.position.name pass.outswinging  \
# 4                      NaN                      NaN              NaN
# 7                      NaN                      NaN              NaN
# 10                     NaN                      NaN              NaN
#
#     pass.technique.id pass.technique.name clearance.aerial_won clearance.head  \
# 4                 NaN                 NaN                  NaN            NaN
# 7                 NaN                 NaN                  NaN            NaN
# 10                NaN                 NaN                  NaN            NaN
#
#     clearance.body_part.id clearance.body_part.name pass.cross  \
# 4                      NaN                      NaN        NaN
# 7                      NaN                      NaN        NaN
# 10                     NaN                      NaN        NaN
#
#     goalkeeper.outcome.id goalkeeper.outcome.name  interception.outcome.id  \
# 4                     NaN                     NaN                      NaN
# 7                     NaN                     NaN                      NaN
# 10                    NaN                     NaN                      NaN
#
#    interception.outcome.name pass.through_ball off_camera counterpress  \
# 4                        NaN               NaN        NaN          NaN
# 7                        NaN               NaN        NaN          NaN
# 10                       NaN               NaN        NaN          NaN
#
#     goalkeeper.body_part.id goalkeeper.body_part.name  \
# 4                       NaN                       NaN
# 7                       NaN                       NaN
# 10                      NaN                       NaN
#
#     goalkeeper.technique.id goalkeeper.technique.name  dribble.outcome.id  \
# 4                       NaN                       NaN                 NaN
# 7                       NaN                       NaN                 NaN
# 10                      NaN                       NaN                 NaN
#
#    dribble.outcome.name foul_won.defensive pass.deflected block.deflection  \
# 4                   NaN                NaN            NaN              NaN
# 7                   NaN                NaN            NaN              NaN
# 10                  NaN                NaN            NaN              NaN
#
#    pass.goal_assist  foul_committed.card.id foul_committed.card.name  \
# 4               NaN                     NaN                      NaN
# 7               NaN                     NaN                      NaN
# 10              NaN                     NaN                      NaN
#
#    clearance.right_foot foul_committed.advantage foul_won.advantage  \
# 4                   NaN                      NaN                NaN
# 7                   NaN                      NaN                NaN
# 10                  NaN                      NaN                NaN
#
#    foul_committed.offensive  foul_committed.type.id foul_committed.type.name  \
# 4                       NaN                     NaN                      NaN
# 7                       NaN                     NaN                      NaN
# 10                      NaN                     NaN                      NaN
#
#    shot.one_on_one dribble.overrun shot.aerial_won goalkeeper.success_in_play  \
# 4              NaN             NaN             NaN                        NaN
# 7              NaN             NaN             NaN                        NaN
# 10             NaN             NaN             NaN                        NaN
#
#    clearance.left_foot  bad_behaviour.card.id bad_behaviour.card.name  \
# 4                  NaN                    NaN                     NaN
# 7                  NaN                    NaN                     NaN
# 10                 NaN                    NaN                     NaN
#
#     substitution.outcome.id substitution.outcome.name  \
# 4                       NaN                       NaN
# 7                       NaN                       NaN
# 10                      NaN                       NaN
#
#     substitution.replacement.id substitution.replacement.name  \
# 4                           NaN                           NaN
# 7                           NaN                           NaN
# 10                          NaN                           NaN
#
#    ball_recovery.offensive pass.cut_back dribble.nutmeg block.offensive  \
# 4                      NaN           NaN            NaN             NaN
# 7                      NaN           NaN            NaN             NaN
# 10                     NaN           NaN            NaN             NaN
#
#    pass.inswinging
# 4              NaN
# 7              NaN
# 10             NaN

# %%
# Yöntem 1: value_counts
shots_per_team = shots["team.name"].value_counts().rename("shots")
print(shots_per_team)

# En çok şut çeken takım:
print("Top team:", shots_per_team.idxmax(), "→", shots_per_team.max())
# Out:
# team.name
# Real Madrid    17
# Barcelona      11
# Name: shots, dtype: int64
# Top team: Real Madrid → 17

# %%
oyuncu_pas_sayilari = passes["player.name"].value_counts()
print(oyuncu_pas_sayilari)

print("En Pasör Oyuncu:", oyuncu_pas_sayilari.idxmax(), "→", oyuncu_pas_sayilari.max() )
# Out:
# player.name
# Ivan Rakitić                           86
# Sergio Busquets i Burgos               83
# Luka Modrić                            74
# Toni Kroos                             72
# Marcelo Vieira da Silva Júnior         72
# Lionel Andrés Messi Cuccittini         61
# Andrés Iniesta Luján                   58
# Sergio Ramos García                    57
# Jordi Alba Ramos                       48
# José Ignacio Fernández Iglesias        46
# Gerard Piqué Bernabéu                  45
# Karim Benzema                          43
# Sergi Roberto Carnicer                 41
# Carlos Henrique Casimiro               39
# Samuel Yves Umtiti                     36
# Marco Asensio Willemsen                36
# Raphaël Varane                         35
# Marc-André ter Stegen                  34
# Gareth Frank Bale                      34
# Luis Alberto Suárez Díaz               29
# Philippe Coutinho Correia              25
# Lucas Vázquez Iglesias                 24
# Keylor Navas Gamboa                    20
# Nélson Cabral Semedo                   19
# Cristiano Ronaldo dos Santos Aveiro    16
# José Paulo Bezzera Maciel Júnior       15
# Mateo Kovačić                          12
# Francisco Alcácer García                1
# Name: count, dtype: int64
# En Pasör Oyuncu: Ivan Rakitić → 86

# %%
en_cok_pas_alan_oyuncular = passes["pass.recipient.name"].value_counts()
print(en_cok_pas_alan_oyuncular)

print("En Çok Pas Alan Oyuncu:", en_cok_pas_alan_oyuncular.idxmax(), "→", en_cok_pas_alan_oyuncular.max() )
# Out:
# pass.recipient.name
# Ivan Rakitić                           79
# Luka Modrić                            76
# Marcelo Vieira da Silva Júnior         71
# Sergio Busquets i Burgos               71
# Lionel Andrés Messi Cuccittini         70
# Toni Kroos                             68
# Andrés Iniesta Luján                   60
# Karim Benzema                          49
# Sergio Ramos García                    45
# José Ignacio Fernández Iglesias        40
# Jordi Alba Ramos                       40
# Gareth Frank Bale                      38
# Marco Asensio Willemsen                37
# Luis Alberto Suárez Díaz               37
# Gerard Piqué Bernabéu                  36
# Sergi Roberto Carnicer                 36
# Samuel Yves Umtiti                     35
# Carlos Henrique Casimiro               31
# Philippe Coutinho Correia              29
# Cristiano Ronaldo dos Santos Aveiro    25
# Raphaël Varane                         23
# Lucas Vázquez Iglesias                 22
# José Paulo Bezzera Maciel Júnior       18
# Nélson Cabral Semedo                   16
# Mateo Kovačić                          11
# Marc-André ter Stegen                  10
# Keylor Navas Gamboa                     7
# Francisco Alcácer García                1
# Name: count, dtype: int64
# En Çok Pas Alan Oyuncu: Ivan Rakitić → 79
